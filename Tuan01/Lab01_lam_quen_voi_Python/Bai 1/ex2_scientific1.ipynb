# %% [markdown]
# # ex2_scientific1
#
# ## Nội dung bài
#
# Hiển thị ngẫu nhiên $N=50$ hình tròn:
# + Tâm $c_i = (x_i,y_i)$ ngẫu nhiên với $x_i, y_i \in \left[0, 1 \right]$
# + Màu sắc $color_i$ ngẫu nhiên với $color_i \in \left[0, 1 \right]$
# + Diện tích $area_i = \pi * r_i^2$ với sinh ngẫu nhiên $r_i \in \left[0, 1 \right]$
#
# ## Bài làm

# %% [markdown]
# ### Import thư viện

# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython import display # hiển thị rich output

# %% [markdown]
# ### Sinh ngẫu nhiên hình tròn

# %%
# %time
# generate randomly the center (x,y ) of circle, color, area
N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = np.pi * (15 * np.random.rand(N)) ** 2  # 0 to 15 point radii
# Out:
# CPU times: total: 0 ns
# Wall time: 10.5 μs

# %%
# Mã kiểm tra dữ liệu
print(f'+ x: len={len(x):d}, [{min(x):.2f}, {max(x):.2f}]: 10 samples [{x[0:10]}]')
print(f'+ y: len={len(y):d}, [{min(y):.2f}, {max(y):.2f}]: 10 samples [{y[0:10]}]')
print(f'+ colors: len={len(colors):d}, [{min(colors):.2f}, {max(colors):.2f}]: 10 samples [{colors[0:10]}]')
print(f'+ area: len={len(area):d}, [{min(area):.2f}, {max(area):.2f}]: 10 samples [{area[0:10]}]')
# Out:
# + x: len=50, [0.01, 0.97]: 10 samples [[0.22220124 0.12670038 0.13515106 0.62945382 0.36165255 0.52252628
#  0.61691521 0.42600317 0.87537501 0.88026018]]
# + y: len=50, [0.01, 1.00]: 10 samples [[0.1142795  0.27777076 0.35423975 0.09575801 0.9686982  0.20867268
#  0.88675843 0.26263996 0.58394905 0.11736179]]
# + colors: len=50, [0.01, 1.00]: 10 samples [[0.77137804 0.54451039 0.72424429 0.34864879 0.27615753 0.11848755
#  0.68463923 0.36091488 0.29101344 0.40956059]]
# + area: len=50, [0.16, 698.25]: 10 samples [[451.8535622  175.30376324   5.5893976  230.16104012  69.30917324
#   27.69361784  20.35299382  51.45145802 526.95895201 129.51846098]]

# %% [markdown]
# ### Hiển thị đồ thị

# %%
# %matplotlib inline
plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.show()

# %% [markdown]
# # Kết thúc
